# %%
import pandas as pd
# import yfinance as yf

# %%
zero = pd.read_csv('./ZeroTrade.csv')
zero
# Out:
#         symbol          isin  trade_date exchange segment series trade_type  \
# 0     RELIANCE  INE002A01018  2022-09-06      NSE      EQ     EQ        buy
# 1          M&M  INE101A01026  2022-09-07      NSE      EQ     EQ        buy
# 2        TECHM  INE669C01036  2022-09-07      NSE      EQ     EQ        buy
# 3         INFY  INE009A01021  2022-09-08      NSE      EQ     EQ        buy
# 4        WIPRO  INE075A01022  2022-09-08      NSE      EQ     EQ        buy
# 5   NATIONALUM  INE139A01034  2022-09-09      NSE      EQ     EQ        buy
# 6          TCS  INE467B01029  2022-09-12      NSE      EQ     EQ        buy
# 7        WIPRO  INE075A01022  2022-09-12      BSE      EQ      A        buy
# 8          M&M  INE101A01026  2022-09-12      NSE      EQ     EQ        buy
# 9        TECHM  INE669C01036  2022-09-12      NSE      EQ     EQ        buy
# 10        SBIN  INE062A01020  2022-09-13      NSE      EQ     EQ        buy
# 11   ICICIBANK  INE090A01021  2022-09-13      NSE      EQ     EQ        buy
# 12  BANKBARODA  INE028A01039  2022-09-13      NSE      EQ     EQ        buy
# 13       TECHM  INE669C01036  2022-09-14      NSE      EQ     EQ        buy
# 14       TECHM  INE669C01036  2022-09-16      NSE      EQ     EQ        buy
# 15       WIPRO  INE075A01022  2022-09-16      BSE      EQ      A       sell
# 16        SBIN  INE062A01020  2022-09-16      NSE      EQ     EQ       sell
# 17        SBIN  INE062A01020  2022-09-16      NSE      EQ     EQ       sell
# 18         M&M  INE101A01026  2022-09-16      NSE      EQ     EQ        buy
# 19  NATIONALUM  INE139A01034  2022-09-20      BSE      EQ      A        buy
# 20    RELIANCE  INE002A01018  2022-09-30      BSE      EQ      A        buy
# 21       TECHM  INE669C01036  2022-09-30      BSE      EQ      A        buy
# 22  NATIONALUM  INE139A01034  2022-09-30      BSE      EQ      A        buy
# 23   ICICIBANK  INE090A01021  2022-09-30      BSE      EQ      A        buy
# 24        SBIN  INE062A01020  2022-09-30      BSE      EQ      A        buy
# 25         PNB  INE160A01022  2022-09-30      NSE      EQ     EQ        buy
# 26         TCS  INE467B01029  2022-10-03      BSE      EQ      A        buy
# 27        INFY  INE009A01021  2022-10-03      NSE      EQ     EQ        buy
# 28    HDFCBANK  INE040A01034  2022-10-10      NSE      EQ     EQ        buy
# 29  TATAMOTORS  INE155A01022  2022-10-10      NSE      EQ     EQ        buy
# 30       TECHM  INE669C01036  2022-10-11      BSE      EQ      A        buy
# 31    RELIANCE  INE002A01018  2022-10-11      NSE      EQ     EQ        buy
# 32    RELIANCE  INE002A01018  2022-10-13      NSE      EQ     EQ        buy
# 33       TECHM  INE669C01036  2022-10-13      BSE      EQ      A        buy
# 34       WIPRO  INE075A01022  2022-10-13      NSE      EQ     EQ        buy
# 35  NATIONALUM  INE139A01034  2022-10-13      BSE      EQ      A        buy
# 36       TECHM  INE669C01036  2022-10-27      BSE      EQ      A       sell
# 37       TECHM  INE669C01036  2022-10-27      BSE      EQ      A       sell
# 38    RELIANCE  INE002A01018  2022-10-27      BSE      EQ      A       sell
# 39    RELIANCE  INE002A01018  2022-10-27      BSE      EQ      A       sell
# 40        INFY  INE009A01021  2022-10-27      NSE      EQ     EQ       sell
# 41         TCS  INE467B01029  2022-10-27      NSE      EQ     EQ       sell
# 42  NATIONALUM  INE139A01034  2022-11-03      BSE      EQ      A        buy
# 43       TECHM  INE669C01036  2022-11-03      NSE      EQ     EQ        buy
# 44       TECHM  INE669C01036  2022-11-03      NSE      EQ     EQ        buy
# 45         M&M  INE101A01026  2022-11-03      BSE      EQ      A        buy
# 46         M&M  INE101A01026  2022-11-03      BSE      EQ      A        buy
# 47  TATAMOTORS  INE155A01022  2022-11-03      NSE      EQ     EQ        buy
#
#     quantity    price  trade_id             order_id order_execution_time
# 0        2.0  2597.35  78918837     1300000018227567  2022-09-06T13:26:46
# 1        1.0  1287.90  51747738     1200000009815661  2022-09-07T11:27:39
# 2        1.0  1057.45  77975089     1300000015259796  2022-09-07T12:26:06
# 3        1.0  1474.45  25386246     1100000001909320  2022-09-08T09:24:03
# 4        2.0   412.60  79800899     1300000025611100  2022-09-08T14:56:34
# 5        1.0    80.65  50492573     1200000002655192  2022-09-09T09:37:10
# 6        1.0  3250.00  76907288     1300000008768827  2022-09-12T11:02:27
# 7        1.0   422.60   5295100  1662953400110501523  2022-09-12T11:03:24
# 8        1.0  1299.95  51596195     1200000008000548  2022-09-12T11:05:24
# 9        1.0  1154.20  76952474     1300000008969006  2022-09-12T11:06:48
# 10       5.0   558.40  75106602     1300000000485337  2022-09-13T09:16:22
# 11       5.0   910.35  25107484     1100000000507523  2022-09-13T09:16:32
# 12       5.0   139.45    175686     1000000000664439  2022-09-13T09:18:20
# 13       1.0  1106.95  76436892     1300000006959730  2022-09-14T10:03:56
# 14       3.0  1032.75  81789714     1300000030341921  2022-09-16T15:10:14
# 15       3.0   401.05  15178600  1663319611769224698  2022-09-16T15:16:08
# 16       1.0   562.00  82147645     1300000031185909  2022-09-16T15:18:23
# 17       1.0   562.20  82185168     1300000031263186  2022-09-16T15:19:04
# 18       2.0  1250.05  55721550     1200000029459763  2022-09-16T15:19:33
# 19      10.0    75.90    276400  1663644600063021228  2022-09-20T09:19:17
# 20       2.0  2371.15   4972200  1664508600040586773  2022-09-30T12:08:02
# 21       2.0  1003.00   3640300  1664508600040749781  2022-09-30T12:09:52
# 22       5.0    70.10   5635000  1664508600041784063  2022-09-30T12:10:51
# 23       2.0   855.15   3661300  1664508600040743641  2022-09-30T12:12:11
# 24       2.0   529.00   3785700  1664508600046603983  2022-09-30T12:12:42
# 25       3.0    36.30  52131344     1200000014530212  2022-09-30T12:13:43
# 26       1.0  2985.90   1918100  1664767800061230164  2022-10-03T09:49:42
# 27       1.0  1392.75  25946034     1100000005382339  2022-10-03T09:52:45
# 28       1.0  1401.95  25269375     1100000001270686  2022-10-10T09:21:01
# 29       3.0   395.75  75329368     1300000001485995  2022-10-10T09:22:09
# 30       1.0  1032.65    406700  1665458101043062905  2022-10-11T09:28:05
# 31       1.0  2387.90  75520480     1300000002548847  2022-10-11T09:30:39
# 32       2.0  2364.20  75734854     1300000003658889  2022-10-13T09:42:09
# 33       3.0  1006.55    517000  1665631800259111735  2022-10-13T09:42:35
# 34       5.0   382.15  76948139     1300000009842249  2022-10-13T11:21:30
# 35       4.0    71.30   2457900  1665631800138625824  2022-10-13T11:22:45
# 36       8.0  1082.10   1751200  1666841400044599342  2022-10-27T10:18:26
# 37       4.0  1082.15   1751000  1666841400044599342  2022-10-27T10:18:26
# 38       2.0  2433.95   5464700  1666854527216145527  2022-10-27T13:19:42
# 39       5.0  2434.00   5464500  1666854527216145527  2022-10-27T13:19:42
# 40       2.0  1520.10  28062705     1100000017201486  2022-10-27T13:21:33
# 41       2.0  3161.20  78406265     1300000017034940  2022-10-27T13:22:54
# 42      10.0    71.40   1195400  1667445336011423320  2022-11-03T09:53:31
# 43       5.0  1059.35  76291814     1300000006786049  2022-11-03T10:21:05
# 44       5.0  1052.60  78070346     1300000016528480  2022-11-03T13:27:27
# 45       1.0  1334.80   2479800  1667457395353495437  2022-11-03T14:06:08
# 46       1.0  1334.85   2480000  1667457395353495437  2022-11-03T14:06:08
# 47       3.0   416.55  78539362     1300000019048307  2022-11-03T14:15:09

# %%
zero.trade_type.map({'buy': 1, 'sell': -1})
data = pd.DataFrame(index=zero.index)

# %%
data['Stock'] = zero.symbol
data['Price'] = zero.price
data['Qty'] = zero.trade_type.map({'buy': 1, 'sell': -1}) * zero.quantity
data['Amount'] = data['Price'] * data['Qty']

# %%
data
# Out:
#          Stock    Price   Qty    Amount
# 0     RELIANCE  2597.35   2.0   5194.70
# 1          M&M  1287.90   1.0   1287.90
# 2        TECHM  1057.45   1.0   1057.45
# 3         INFY  1474.45   1.0   1474.45
# 4        WIPRO   412.60   2.0    825.20
# 5   NATIONALUM    80.65   1.0     80.65
# 6          TCS  3250.00   1.0   3250.00
# 7        WIPRO   422.60   1.0    422.60
# 8          M&M  1299.95   1.0   1299.95
# 9        TECHM  1154.20   1.0   1154.20
# 10        SBIN   558.40   5.0   2792.00
# 11   ICICIBANK   910.35   5.0   4551.75
# 12  BANKBARODA   139.45   5.0    697.25
# 13       TECHM  1106.95   1.0   1106.95
# 14       TECHM  1032.75   3.0   3098.25
# 15       WIPRO   401.05  -3.0  -1203.15
# 16        SBIN   562.00  -1.0   -562.00
# 17        SBIN   562.20  -1.0   -562.20
# 18         M&M  1250.05   2.0   2500.10
# 19  NATIONALUM    75.90  10.0    759.00
# 20    RELIANCE  2371.15   2.0   4742.30
# 21       TECHM  1003.00   2.0   2006.00
# 22  NATIONALUM    70.10   5.0    350.50
# 23   ICICIBANK   855.15   2.0   1710.30
# 24        SBIN   529.00   2.0   1058.00
# 25         PNB    36.30   3.0    108.90
# 26         TCS  2985.90   1.0   2985.90
# 27        INFY  1392.75   1.0   1392.75
# 28    HDFCBANK  1401.95   1.0   1401.95
# 29  TATAMOTORS   395.75   3.0   1187.25
# 30       TECHM  1032.65   1.0   1032.65
# 31    RELIANCE  2387.90   1.0   2387.90
# 32    RELIANCE  2364.20   2.0   4728.40
# 33       TECHM  1006.55   3.0   3019.65
# 34       WIPRO   382.15   5.0   1910.75
# 35  NATIONALUM    71.30   4.0    285.20
# 36       TECHM  1082.10  -8.0  -8656.80
# 37       TECHM  1082.15  -4.0  -4328.60
# 38    RELIANCE  2433.95  -2.0  -4867.90
# 39    RELIANCE  2434.00  -5.0 -12170.00
# 40        INFY  1520.10  -2.0  -3040.20
# 41         TCS  3161.20  -2.0  -6322.40
# 42  NATIONALUM    71.40  10.0    714.00
# 43       TECHM  1059.35   5.0   5296.75
# 44       TECHM  1052.60   5.0   5263.00
# 45         M&M  1334.80   1.0   1334.80
# 46         M&M  1334.85   1.0   1334.85
# 47  TATAMOTORS   416.55   3.0   1249.65

# %%
data['cum_qty'] = data.groupby('Stock')['Qty'].cumsum()
data['cum_Amt'] = data.groupby('Stock')['Amount'].cumsum()
data['cum_Avg'] = data.loc[data['cum_qty'] > 0]['cum_Amt'] / data.loc[data['cum_qty'] > 0]['cum_qty']
data['Profit'] = -1 * data.loc[data['cum_qty'] == 0]['cum_Amt']
data['Profit'] = data['Profit'].fillna(0)
data['%Profit'] = -100 * data['Profit'] / data['Amount']
data['%Profit'] = data.groupby('Stock')['%Profit'].cumsum()
data['cum_profit'] = data.groupby('Stock')['Profit'].cumsum()
data['Invested_amt'] = data['cum_Amt'] + data['cum_profit']
data['apparent_avg'] = data['Invested_amt'] / data['cum_qty']
data['apparent_amt'] = data['apparent_avg'] * data['cum_qty']
data = data.fillna(0)


stock_slice = []
for i in data['Stock'].drop_duplicates():
    stock_df = data.loc[data['Stock'] == i]
    ind_x = stock_df[stock_df['cum_qty'].map(lambda x: x == 0)].index
    stock_slice.append(stock_df.tail(1).index[0])


stock_slice = pd.Index(stock_slice)
foli0 = data.iloc[stock_slice]
foli0 = foli0.set_index('Stock')
foli0 = foli0.sort_index()
foli0.loc['Total'] = foli0.sum(numeric_only=True)
foli0.loc['Total', ['Price','Qty','Amount','cum_Avg','Profit','apparent_avg']] = pd.NA
foli0.loc['Total', ['%Profit']] = 100 * foli0.at['Total', 'cum_profit'] / foli0.at['Total', 'Invested_amt']
print(foli0[['Invested_amt', 'cum_profit', 'cum_qty', 'apparent_avg', 'cum_Avg', '%Profit']])
# Out:
#             Invested_amt  cum_profit  cum_qty apparent_avg  cum_Avg    %Profit
# Stock
# BANKBARODA        697.25        0.00      5.0       139.45   139.45   0.000000
# HDFCBANK         1401.95        0.00      1.0      1401.95  1401.95   0.000000
# ICICIBANK        6262.05        0.00      7.0      894.579  894.579   0.000000
# INFY                0.00      173.00      0.0            0        0   5.690415
# M&M              7757.60        0.00      6.0      1292.93  1292.93   0.000000
# NATIONALUM       2189.35        0.00     30.0      72.9783  72.9783   0.000000
# PNB               108.90        0.00      3.0         36.3     36.3   0.000000
# RELIANCE            0.00      -15.40      0.0            0        0  -0.126541
# SBIN             2725.80        0.00      5.0       545.16   545.16   0.000000
# TATAMOTORS       2436.90        0.00      6.0       406.15   406.15   0.000000
# TCS                 0.00       86.50      0.0            0        0   1.368151
# TECHM           10559.75      510.25     10.0      1055.97  1004.95  11.787876
# WIPRO            1910.75      -44.65      5.0       382.15   391.08  -3.711092
# Total           36050.30      709.70     78.0         <NA>     <NA>   1.968638

# %%
foli0
# Out:
#               Price   Qty   Amount  cum_qty   cum_Amt  cum_Avg Profit  \
# Stock
# BANKBARODA   139.45     5   697.25      5.0    697.25   139.45      0
# HDFCBANK    1401.95     1  1401.95      1.0   1401.95  1401.95      0
# ICICIBANK    855.15     2   1710.3      7.0   6262.05  894.579      0
# INFY         1520.1    -2  -3040.2      0.0   -173.00        0    173
# M&M         1334.85     1  1334.85      6.0   7757.60  1292.93      0
# NATIONALUM     71.4    10      714     30.0   2189.35  72.9783      0
# PNB            36.3     3    108.9      3.0    108.90     36.3      0
# RELIANCE       2434    -5   -12170      0.0     15.40        0  -15.4
# SBIN            529     2     1058      5.0   2725.80   545.16      0
# TATAMOTORS   416.55     3  1249.65      6.0   2436.90   406.15      0
# TCS          3161.2    -2  -6322.4      0.0    -86.50        0   86.5
# TECHM        1052.6     5     5263     10.0  10049.50  1004.95      0
# WIPRO        382.15     5  1910.75      5.0   1955.40   391.08      0
# Total          <NA>  <NA>     <NA>     78.0  35340.60     <NA>   <NA>
#
#               %Profit  cum_profit  Invested_amt apparent_avg  apparent_amt
# Stock
# BANKBARODA   0.000000        0.00        697.25       139.45        697.25
# HDFCBANK     0.000000        0.00       1401.95      1401.95       1401.95
# ICICIBANK    0.000000        0.00       6262.05      894.579       6262.05
# INFY         5.690415      173.00          0.00            0          0.00
# M&M          0.000000        0.00       7757.60      1292.93       7757.60
# NATIONALUM   0.000000        0.00       2189.35      72.9783       2189.35
# PNB          0.000000        0.00        108.90         36.3        108.90
# RELIANCE    -0.126541      -15.40          0.00            0          0.00
# SBIN         0.000000        0.00       2725.80       545.16       2725.80
# TATAMOTORS   0.000000        0.00       2436.90       406.15       2436.90
# TCS          1.368151       86.50          0.00            0          0.00
# TECHM       11.787876      510.25      10559.75      1055.97      10559.75
# WIPRO       -3.711092      -44.65       1910.75       382.15       1910.75
# Total        1.968638      709.70      36050.30         <NA>      36050.30
